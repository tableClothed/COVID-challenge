# %%
import nltk
import pandas as pd
import os
import pycountry
import numpy as np
import spacy
import allcities
import warnings; warnings.simplefilter('ignore')

# %%
nlp = spacy.load('en_core_web_lg')

# %%
countries = ['china', 'japan', 'korea', 'taiwan', 'hong', 'vietnam', 'india', 'russia', 'indonesia',
            'philippines', 'singapore', 'thailand', 'iran', 'iraq', 'pakistan', 'qatar']

# %%
df = pd.read_csv("csvfiles/metadata.csv")
df = df[['title', 'publish_time', 'abstract']]
df['publish_time'] = pd.to_datetime(df['publish_time'])
ids = (df['publish_time'] > '2019-12-01')
clean_df = df[ids].dropna().reset_index()
del clean_df['index']
clean_df
# Out:
#                                                   title publish_time  \
# 0     Delving Below the Species Level To Characteriz...   2019-12-13
# 1     Novel splicing and open reading frames reveale...   2019-12-13
# 2     Non-uniform refinement: Adaptive regularizatio...   2019-12-16
# 3     Randomly primed, strand-switching MinION-based...   2019-12-16
# 4     Stochastic challenges to interrupting helminth...   2019-12-18
# ...                                                 ...          ...
# 3107  The response of Milan's Emergency Medical Syst...   2020-03-20
# 3108  Quantitative computed tomography analysis for ...   2020-03-06
# 3109  The SARS-CoV-2 outbreak from a one health pers...   2020-03-16
# 3110  One-tube smart genetic testing via coupling is...   2020-04-15
# 3111                   Why the WHO won't use the p-word   2020-03-07
#
#                                                abstract
# 0     SummaryEfforts to describe the diversity of vi...
# ...

# %%
tags =

# %%
new_df = df.loc[relevant].drop_duplicates()
new_df
# Out:
#                                                    title  \
# 1      Analysis Title: Regaining perspective on SARS-...
# 2      Healthcare-resource-adjusted vulnerabilities t...
# 3      Real-time, MinION-based, amplicon sequencing f...
# 4      A Combined Evidence Approach to Prioritize Nip...
# 5      Assessing spread risk of Wuhan novel coronavir...
# ...                                                  ...
# 33369  More than efficacy revealed by single-cell ana...
# 33370          Understanding Human Coronavirus HCoV-NL63
# 33372  Identification of a Subdomain of CENPB That Is...
# 33373  Replication enhancer elements within the open ...
# 33374  Supplemental material for the paper "Evidence ...
#
#                                                 abstract  \
# 1      During the past three months, a new coronaviru...
# 2                                                     []
# 3      Infectious bronchitis (IB) causes significant ...
# ...

# %%
new_df.to_csv("asian_countries.csv")
