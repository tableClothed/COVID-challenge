# %%
import nltk
import pandas as pd
import os
import pycountry
import numpy as np
import spacy
import warnings; warnings.simplefilter('ignore')

# %%
nlp = spacy.load('en_core_web_lg')

DIR = "csvfiles/tasks/"
TAGS = [
    nlp("transmission incubation environment seasonality prevalence shedding role"),
    nlp('risk smoking infections pregnancy fatality'),
    nlp('genetics origin evolution animal range host'),
    nlp('vaccines therapeutics drugs antibody effectiveness'),
    nlp('medical manifestations respirators technologies protection'),
    nlp('pharmaceutical closures ban gatherings depending'),
    nlp("diagnostics surveillance policy technology"),
    "",
    nlp("ethical social education access fear"),
    nlp('government published surveillance policy')
]

# %%
def find_similarity(df, tags):
    task = []
    for i, row in df.iterrows():
        try:
            title = row[1].lower()
            title = nlp(title)
            result = title.similarity(tags)
            task.append([i, result])
        except Exception as e: print(e)
            
    sorted_results = sorted(task, key=lambda x: x[1], reverse=True)[:20]
    ids = [i for i, r in sorted_results]
    dataframe = df.loc[ids]
    dataframe = dataframe.reset_index(drop=True)
    prob = pd.DataFrame({"similarity": [r for i, r in sorted_results]})
    dataframe = dataframe.join(prob)     
        
    return dataframe

# %%
def find_final_dataframe(task_num):
    df = pd.read_csv(DIR + "task" + str(task_num) + ".csv")
    
    tags = TAGS[task_num-1]
    paragraphs, par_id = [], []

    for i, row in df.iterrows():
        sentences = row[2].split('.')
        for sentence in sentences:
            sentence_changed = (sentence.replace('.', '').replace(' ', '').replace(';', '')
                                .replace(':', '').replace(',', '').replace('\n', '').replace("'", '')
                                .replace('"', '').lower())
            if len(sentence_changed) < 40:
                continue
            if sentence_changed not in paragraphs:
                sentence = sentence.replace('\n', '')
                paragraphs.append(sentence_changed)
                par_id.append([i, sentence])
    new_df = pd.DataFrame(par_id)
    final_df = find_similarity(new_df, tags)
    return final_df

# %%
def read_result(task):
    for i, r in task.iterrows():
        print('------------------------')
        print(df.loc[r[0]]['title'].upper())
        print('------------------------')
        print(r[1])
        print('\n\n')

# %% [markdown]
# # TASK 1
# ## What is known about transmission, incubation, and environmental stability?
# - Range of incubation periods for the disease in humans (and how this varies across age and health status) and how long individuals are contagious, even after recovery.
# - Prevalence of asymptomatic shedding and transmission (e.g., particularly children).
# - Seasonality of transmission.
# - Physical science of the coronavirus (e.g., charge distribution, adhesion to hydrophilic/phobic surfaces, environmental survival to inform decontamination efforts for affected areas and provide information about viral shedding).
# - Persistence and stability on a multitude of substrates and sources (e.g., nasal discharge, sputum, urine, fecal matter, blood).
# - Persistence of virus on surfaces of different materials (e,g., copper, stainless steel, plastic).
# - Natural history of the virus and shedding of it from an infected person
# - Implementation of diagnostics and products to improve clinical processes
# - Disease models, including animal models for infection, disease and transmission
# - Tools and studies to monitor phenotypic change and potential adaptation of the virus
# - Immune response and immunity
# - Effectiveness of movement control strategies to prevent secondary transmission in health care and community settings
# - Effectiveness of personal protective equipment (PPE) and its usefulness to reduce risk of transmission in health care and community settings
# - Role of the environment in transmission

# %%
task = find_final_dataframe(1)
task
# Out:
#      0                                                  1  similarity
# 0    2  Animal models have elucidated potential mechan...    0.715445
# 1   26  Transmission bottlenecks can define subsequent...    0.715092
# 2    9     Quantifying the temporal transmission dynamics    0.705834
# 3    1   Host factors control viral transmission withi...    0.698195
# 4   33   In addition to storage temperature, porosity ...    0.697143
# 5   47   to interpolate contours of transmission of in...    0.691115
# 6   30  Mechanisms of viral transmissions are sometime...    0.687488
# 7   16  Disease dynamics within populations are primar...    0.685996
# 8   38   The Rluc activity reflects influenza replicat...    0.685671
# 9    0   Here, we Environmental Conditions Affect Infl...    0.681191
# 10  34  Understanding transmission of influenza and th...    0.678829
# 11  25   Latent, incubation, infectious and symptomati...    0.678205
# 12  29   This study explores the seasonality and preva...    0.676581
# 13  22   Aerosol transmission involves any transmissio...    0.676168
# 14  37  Relationship between the incubation period of ...    0.675021
# 15  33   It appears that low storage temperature delay...    0.674113
# 16   3   7 Conversely, the virus must also maintain it...    0.672015
# 17  27   The virulence risk factors we identify sugges...    0.670940
# 18   1   Infection by an environmental route that sele...    0.670055
# 19  23  We investigated the effect of enhanced hygiene...    0.669470

# %%
read_result(task)
# Out:
# ------------------------
# PREGNANCY AND PERINATAL OUTCOMES OF WOMEN WITH SEVERE ACUTE RESPIRATORY SYNDROME
# ------------------------
# Animal models have elucidated potential mechanisms by which humidity and temperature influence human influenza virus transmission
#
#
#
# ------------------------
# OBESITY AND RISK OF RESPIRATORY TRACT INFECTIONS: RESULTS OF AN INFECTION-DIARY BASED COHORT STUDY
# ------------------------
# Transmission bottlenecks can define subsequent viral evolution
#
#
#
# ------------------------
# STATINS MAY DECREASE THE FATALITY RATE OF MIDDLE EAST RESPIRATORY SYNDROME INFECTION
# ------------------------
# Quantifying the temporal transmission dynamics
#
#
#
# ------------------------
# EXERCISE AND INFECTION RISK
# ------------------------
#  Host factors control viral transmission within the bird
#
#
#
# ------------------------
# OPEN FORUM INFECTIOUS DISEASES ® FEBRILE RHINOVIRUS ILLNESS DURING PREGNANCY IS ASSOCIATED WITH LOW BIRTH WEIGHT IN NEPAL
# ------------------------
#  In addition to storage temperature, porosity of fomite may also influence virus survival and hence virus transmission
#
#
#
# ------------------------
# EPIDEMIOLOGY OF VIRAL RESPIRATORY INFECTIONS IN CHILDREN UNDERGOING HEART SURGERY
# ------------------------
#  to interpolate contours of transmission of influenza in the humidity versus temperature phase space
#
#
#
# ------------------------
# OUTCOME RISK FACTORS DURING RESPIRATORY INFECTIONS IN A PAEDIATRIC WARD IN ANTANANARIVO
# ------------------------
# Mechanisms of viral transmissions are sometimes correlated with genetic diversity dynamics
#
#
#
# ------------------------
# VIRAL INFECTION IN ADULTS WITH SEVERE ACUTE RESPIRATORY INFECTION IN COLOMBIA
# ------------------------
# Disease dynamics within populations are primarily driven by interactions among the processes of pathogen transmission and clearance, immunity, and host population dynamics
#
#
#
# ------------------------
# VIRAL CO-INFECTIONS IN PEDIATRIC PATIENTS HOSPITALIZED WITH LOWER TRACT ACUTE RESPIRATORY INFECTIONS
# ------------------------
#  The Rluc activity reflects influenza replication levels
#
#
#
# ------------------------
# RESPIRATORY DISEASE IN PREGNANCY
# ------------------------
#  Here, we Environmental Conditions Affect Influenza Transmission in Ferrets evaluated the transmissibility of two H3N2 influenza viruses (PN99 and IN11) using ferrets housed under diverse environmental conditions and concurrently evaluated the aerosol shedding profiles of infected animals
#
#
#
# ------------------------
# POSTNATAL INFECTIONS AND IMMUNOLOGY AFFECTING CHRONIC LUNG DISEASE OF PREMATURITY
# ------------------------
# Understanding transmission of influenza and the factors that affect transmission is crucial for designing effective control strategies
#
#
#
# ------------------------
# EPIDEMIOLOGY OF SEVERE ACUTE RESPIRATORY ILLNESS AND RISK FACTORS FOR INFLUENZA INFECTION AND CLINICAL SEVERITY AMONG ADULTS IN MALAWI, 2011-2013
# ------------------------
#  Latent, incubation, infectious and symptomatic periods with further data
#
#
#
# ------------------------
# COMPARING HUMAN METAPNEUMOVIRUS AND RESPIRATORY SYNCYTIAL VIRUS: VIRAL CO- DETECTIONS, GENOTYPES AND RISK FACTORS FOR SEVERE DISEASE
# ------------------------
#  This study explores the seasonality and prevalence of respiratory viral pathogens at a tertiary care medical center using the multiplex PCR respiratory pathogen panel
#
#
#
# ------------------------
# HOSPITAL-ACQUIRED RESPIRATORY VIRAL INFECTIONS: INCIDENCE, MORBIDITY, AND MORTALITY IN PEDIATRIC AND ADULT PATIENTS
# ------------------------
#  Aerosol transmission involves any transmission mediated by aerosol droplets
#
#
#
# ------------------------
# EMERGING INFECTIONS AND PREGNANCY: WEST NILE VIRUS, MONKEYPOX, SEVERE ACUTE RESPIRATORY SYNDROME, AND BIOTERRORISM
# ------------------------
# Relationship between the incubation period of influenza virus and the immune response
#
#
#
# ------------------------
# OPEN FORUM INFECTIOUS DISEASES ® FEBRILE RHINOVIRUS ILLNESS DURING PREGNANCY IS ASSOCIATED WITH LOW BIRTH WEIGHT IN NEPAL
# ------------------------
#  It appears that low storage temperature delays virus degradation on fomite material
#
#
#
# ------------------------
# SEVERE MORBIDITY AND MORTALITY ASSOCIATED WITH RESPIRATORY SYNCYTIAL VIRUS VERSUS INFLUENZA INFECTION IN HOSPITALIZED OLDER ADULTS
# ------------------------
#  7 Conversely, the virus must also maintain its stability in variable extracellular pH environments in its transmission between hosts
#
#
#
# ------------------------
# ESTIMATING THE RISKS FROM COVID-19 INFECTION IN ADULT CHEMOTHERAPY PATIENTS
# ------------------------
#  The virulence risk factors we identify suggest that broadly targeting direct contact or respiratory transmission interfaces within ecological systems and/or tailoring detection assays towards certain virus families (e
#
#
#
# ------------------------
# EXERCISE AND INFECTION RISK
# ------------------------
#  Infection by an environmental route that selectively allowed cloacal shedding and onward transmission would have a profound effect on the transmission dynamics and persistence of avian influenza viruses in the wild 27
#
#
#
# ------------------------
# RISK FACTORS RELATED TO HEPATIC INJURY IN PATIENTS WITH CORONA VIRUS DISEASE 2019
# ------------------------
# We investigated the effect of enhanced hygiene measures on reducing norovirus transmission during an outbreak

# %% [markdown]
# # TASK 2
# ## What do we know about COVID-19 risk factors? What have we learned from epidemiological studies?
# - Data on potential risks factors
# - Smoking, pre-existing pulmonary disease
# - Co-infections (determine whether co-existing respiratory/viral infections make the virus more transmissible or virulent) and other co-morbidities
# - Neonates and pregnant women
# - Socio-economic and behavioral factors to understand the economic impact of the virus and whether there were differences.
# - Transmission dynamics of the virus, including the basic reproductive number, incubation period, serial interval, modes of transmission and environmental factors
# - Severity of disease, including risk of fatality among symptomatic hospitalized patients, and high-risk patient groups
# - Susceptibility of populations
# - Public health mitigation measures that could be effective for control

# %%
task = find_final_dataframe(2)
task
# Out:
#      0                                                  1  similarity
# 0   32   Prevention of respiratory viral infections ma...    0.857415
# 1   28   29 In addition to heightened maternal disease...    0.824758
# 2    2   Given the significant maternal and perinatal ...    0.816071
# 3    4   Influenza infection during pregnancy is assoc...    0.810363
# 4    0  Effect of pneumonia on pregnancy: Severe pneum...    0.808511
# 5   32   10 We hypothesized that during pregnancy, wom...    0.808511
# 6   31  RV infection and allergic sensitization synerg...    0.805921
# 7   11   Hence, epidemiological studies excluding pati...    0.805888
# 8    0  Influenza vaccination can reduce the prevalenc...    0.802891
# 9   47   studied incidence and etiology of viral infec...    0.800591
# 10   0   Coexisting maternal disease, including asthma...    0.799480
# 11  28   Infection with these viruses during pregnancy...    0.798755
# 12   0  Effects of pregnancy on pneumonia: Pneumonia i...    0.798571
# 13   6  Infection with respiratory pathogens during pr...    0.798083
# 14   0  Viral pneumonia Viral respiratory infections, ...    0.797371
# 15   3   The greater use of antibiotics and systemic a...    0.797091
# 16   0  Severe chest disease leading to respiratory fa...    0.796753
# 17  32   21 Pregnant women with asthma are at increase...    0.796730
# 18  28   23 Varicella zoster virus (VZV) is another va...    0.794699
# 19  32   Women with asthma with PCR-positive colds had...    0.793821

# %%
read_result(task)
# Out:
# ------------------------
# A PROSPECTIVE STUDY OF RESPIRATORY VIRAL INFECTION IN PREGNANT WOMEN WITH AND WITHOUT ASTHMA
# ------------------------
#  Prevention of respiratory viral infections may improve asthma outcomes during pregnancy
#
#
#
# ------------------------
# PREGNANCY AND INFECTION: USING DISEASE PATHOGENESIS TO INFORM VACCINE STRATEGY
# ------------------------
#  29 In addition to heightened maternal disease severity, HEV infection during pregnancy is associated with increased rates of premature birth and prenatal mortality
#
#
#
# ------------------------
# PREGNANCY AND PERINATAL OUTCOMES OF WOMEN WITH SEVERE ACUTE RESPIRATORY SYNDROME
# ------------------------
#  Given the significant maternal and perinatal morbidity and mortality of most viral pneumonia in pregnancy, SARS may impose greater risk in pregnant compared to nonpregnant individuals
#
#
#
# ------------------------
# CLINICAL PRESENTATION AND BIRTH OUTCOMES ASSOCIATED WITH RESPIRATORY SYNCYTIAL VIRUS INFECTION IN PREGNANCY
# ------------------------
#  Influenza infection during pregnancy is associated with increased maternal and neonatal morbidity and mortality [4]
#
#
#
# ------------------------
# RESPIRATORY DISEASE IN PREGNANCY
# ------------------------
# Effect of pneumonia on pregnancy: Severe pneumonia may precipitate preterm delivery and result in low birthweight infants
#
#
#
# ------------------------
# A PROSPECTIVE STUDY OF RESPIRATORY VIRAL INFECTION IN PREGNANT WOMEN WITH AND WITHOUT ASTHMA
# ------------------------
#  10 We hypothesized that during pregnancy, women with asthma experience more frequent and more severe respiratory viral infections than pregnant women without asthma
#
#
#
# ------------------------
# VIRAL INFECTIONS AND ASSOCIATED FACTORS THAT PROMOTE ACUTE EXACERBATIONS OF ASTHMA VIRAL INFECTION AND ASTHMA EXACERBATION VIRAL INFECTION AND ASTHMA EXACERBATION VIRAL INFECTION AND ASTHMA EXACERBATION
# ------------------------
# RV infection and allergic sensitization synergistically increase the risk of wheezing illnesses
#
#
#
# ------------------------
# RESPIRATORY VIRUS INFECTION AMONG HOSPITALIZED ADULT PATIENTS WITH OR WITHOUT CLINICALLY APPARENT RESPIRATORY INFECTION: A PROSPECTIVE COHORT STUDY
# ------------------------
#  Hence, epidemiological studies excluding patients without symptoms or signs of respiratory tract infection may underestimate the true burden of respiratory virus infection
#
#
#
# ------------------------
# RESPIRATORY DISEASE IN PREGNANCY
# ------------------------
# Influenza vaccination can reduce the prevalence of hospitalisations among pregnant women during the influenza season and is not contraindicated in pregnancy
#
#
#
# ------------------------
# EPIDEMIOLOGY OF VIRAL RESPIRATORY INFECTIONS IN CHILDREN UNDERGOING HEART SURGERY
# ------------------------
#  studied incidence and etiology of viral infections among hospitalized children with VRI symptoms
#
#
#
# ------------------------
# RESPIRATORY DISEASE IN PREGNANCY
# ------------------------
#  Coexisting maternal disease, including asthma and anaemia, and immunosuppressive therapy increase the risk of contracting pneumonia
#
#
#
# ------------------------
# PREGNANCY AND INFECTION: USING DISEASE PATHOGENESIS TO INFORM VACCINE STRATEGY
# ------------------------
#  Infection with these viruses during pregnancy results in severe maternal disease, increased maternal mortality and associated pregnancy complications, which are observed most frequently during the third trimester and peripartum period
#
#
#
# ------------------------
# RESPIRATORY DISEASE IN PREGNANCY
# ------------------------
# Effects of pregnancy on pneumonia: Pneumonia in pregnancy is often more virulent and mortality is higher than in the nonpregnant population
#
#
#
# ------------------------
# CLINICAL CHARACTERISTICS AND OUTCOMES OF RESPIRATORY SYNCYTIAL VIRUS INFECTION IN PREGNANT WOMEN
# ------------------------
# Infection with respiratory pathogens during pregnancy can result in mild to severe acute respiratory illness (ARI)
#
#
#
# ------------------------
# RESPIRATORY DISEASE IN PREGNANCY
# ------------------------
# Viral pneumonia Viral respiratory infections, including varicella, influenza A and severe acute respiratory syndrome (SARS), may present in pregnancy and are associated with a worse outcome than in the non-pregnant population
#
#
#
# ------------------------
# SEVERE MORBIDITY AND MORTALITY ASSOCIATED WITH RESPIRATORY SYNCYTIAL VIRUS VERSUS INFLUENZA INFECTION IN HOSPITALIZED OLDER ADULTS
# ------------------------
#  The greater use of antibiotics and systemic and inhaled steroids in the RSV cohort during their hospitalizations may mirror the higher frequency of pneumonia and exacerbation of chronic lung disease and asthma among older hospitalized adults with RSV infection than those with influenza infection
#
#
#
# ------------------------
# RESPIRATORY DISEASE IN PREGNANCY
# ------------------------
# Severe chest disease leading to respiratory failure is uncommon in women of childbearing age but respiratory symptoms are extremely common in pregnancy
#
#
#
# ------------------------
# A PROSPECTIVE STUDY OF RESPIRATORY VIRAL INFECTION IN PREGNANT WOMEN WITH AND WITHOUT ASTHMA
# ------------------------
#  21 Pregnant women with asthma are at increased risk of preeclampsia compared with pregnant women without asthma
#
#
#
# ------------------------
# PREGNANCY AND INFECTION: USING DISEASE PATHOGENESIS TO INFORM VACCINE STRATEGY
# ------------------------
#  23 Varicella zoster virus (VZV) is another vaccine-preventable infection associated with increased severity during pregnancy
#
#
#
# ------------------------
# A PROSPECTIVE STUDY OF RESPIRATORY VIRAL INFECTION IN PREGNANT WOMEN WITH AND WITHOUT ASTHMA
# ------------------------
#  Women with asthma with PCR-positive colds had signifi cantly increased odds of preeclampsia or pregnancy-induced hypertension when adjusted for known preeclampsia risk factors (maternal smoking, age, BMI, parity, multiple pregnancy; OR, 8

# %% [markdown]
# # TASK 3
# ## What do we know about virus genetics, origin, and evolution? What do we know about the virus origin and management measures at the human-animal interface?
# - Real-time tracking of whole genomes and a mechanism for coordinating the rapid dissemination of that information to inform the development of diagnostics and therapeutics and to track variations of the virus over time.
# - Access to geographic and temporal diverse sample sets to understand geographic distribution and genomic differences, and determine whether there is more than one strain in circulation. Multi-lateral agreements such as the Nagoya Protocol could be leveraged.
# - Evidence that livestock could be infected (e.g., field surveillance, genetic sequencing, receptor binding) and serve as a reservoir after the epidemic appears to be over.
# - Evidence of whether farmers are infected, and whether farmers could have played a role in the origin.
# - Surveillance of mixed wildlife- livestock farms for SARS-CoV-2 and other coronaviruses in Southeast Asia.
# - Experimental infections to test host range for this pathogen.
# - Animal host(s) and any evidence of continued spill-over to humans
# - Socioeconomic and behavioral risk factors for this spill-over
# - Sustainable risk reduction strategies

# %%
task = find_final_dataframe(3)
task
# Out:
#      0                                                  1  similarity
# 0    4  The empirical link between disease spread and ...    0.814726
# 1   42   We investigated the origin and evolutionary h...    0.810797
# 2   15  Comparative studies in nonhuman species are in...    0.810618
# 3   29   We show that even distantly related viruses w...    0.809940
# 4   15   Patterns of divergence describe substantial g...    0.805080
# 5   12  To understand the evolutionary processes of th...    0.804559
# 6   35   japonicum in its natural reservoir hosts and ...    0.804225
# 7   21  In this study, we expanded the fraction of cha...    0.803252
# 8    8  This study has provided the first characteriza...    0.800435
# 9   17   Throughout this review, we highlight uses of ...    0.799735
# 10  44  Because genetics is a science of differences, ...    0.799473
# 11  15  Similarities in the natural history and evolut...    0.798374
# 12  16  Intra-host molecular evolution is also a featu...    0.797322
# 13  15   Comparative studies in nonhuman species are i...    0.797300
# 14  15  The emergence of infectious disease within new...    0.797037
# 15  28   Interestingly, lion and FIV Ple variation rev...    0.796828
# 16  29   Specific hosts impose specific evolutionary l...    0.795997
# 17  15   Molecular genetic analyses of viral strains f...    0.795095
# 18   8   Positive selection at IGHC genes across the m...    0.794831
# 19  37  One of the oldest topics in genetics -natural ...    0.794347

# %%
read_result(task)
# Out:
# ------------------------
# CLINICAL PRESENTATION AND BIRTH OUTCOMES ASSOCIATED WITH RESPIRATORY SYNCYTIAL VIRUS INFECTION IN PREGNANCY
# ------------------------
# The empirical link between disease spread and genetic diversity has its origin in agricultural research
#
#
#
# ------------------------
# INCIDENCE AND IMPLICATIONS OF UNRECOGNIZED VIRAL RESPIRATORY TRACT INFECTIONS IN PREMATURE INFANTS DURING THEIR BIRTH HOSPITALIZATION: A PROSPECTIVE SURVEILLANCE STUDY IN TWO NEONATAL INTENSIVE CARE UNITS NIH PUBLIC ACCESS
# ------------------------
#  We investigated the origin and evolutionary history of this VNTR in human population by clonal sequencing
#
#
#
# ------------------------
# RESPIRATORY VIRAL INFECTIONS AND THE RISK OF RHEUMATOID ARTHRITIS
# ------------------------
# Comparative studies in nonhuman species are invaluable, especially when they incorporate diverse disciplines such as wildlife biology with biomedical and veterinary medicine and thereby stimulate advances in genetic and evolutionary research of both pathogen and host
#
#
#
# ------------------------
# COMPARING HUMAN METAPNEUMOVIRUS AND RESPIRATORY SYNCYTIAL VIRUS: VIRAL CO- DETECTIONS, GENOTYPES AND RISK FACTORS FOR SEVERE DISEASE
# ------------------------
#  We show that even distantly related viruses within a viral family share highly conserved genetic signatures of host specificity; reinforce how fitness landscapes of host adaptation are shaped by host phylogeny; and highlight the evolutionary trajectories of RNA viruses in rapid expansion and under great evolutionary pressure
#
#
#
# ------------------------
# RESPIRATORY VIRAL INFECTIONS AND THE RISK OF RHEUMATOID ARTHRITIS
# ------------------------
#  Patterns of divergence describe substantial genetic differences among strains across the entire FIV genome and define monophyletic viral lineages unique to specific host species (Barr et al
#
#
#
# ------------------------
# ADENOVIRUS RESPIRATORY INFECTION IN HOSPITALIZED CHILDREN IN HONG KONG: SEROTYPE-CLINICAL SYNDROME ASSOCIATION AND RISK FACTORS FOR LOWER RESPIRATORY TRACT INFECTION
# ------------------------
# To understand the evolutionary processes of the primate a-/hdefensin gene family, molecular evolutionary analyses and comparative genomics analyses were performed
#
#
#
# ------------------------
# DISEASE ASSOCIATED WITH EQUINE CORONAVIRUS INFECTION AND HIGH CASE FATALITY RATE
# ------------------------
#  japonicum in its natural reservoir hosts and laboratory animals will undoubtedly facilitate our understanding of parasite biology
#
#
#
# ------------------------
# POTENTIALLY PREVENTABLE URINARY TRACT INFECTION IN PATIENTS WITH TYPE 2 DIABETES -A HOSPITAL-BASED STUDY
# ------------------------
# In this study, we expanded the fraction of characterized microbial diversity in the highly unexplored non-human primate metagenome, to enable species-and strain-level comparative genomics analysis of the human and nonhuman primate microbiome and generate hypotheses on relevant coevolutionary trajectories that shaped the current worldwide structure of the human microbiome
#
#
#
# ------------------------
# VIRUSES CAUSING LOWER RESPIRATORY SYMPTOMS IN YOUNG CHILDREN: FINDINGS FROM THE ORCHID BIRTH COHORT RESPIRATORY INFECTION
# ------------------------
# This study has provided the first characterization of IGHC genes in marine mammals and explored their potential molecular genetic basis in the secondary aquatic adaptation
#
#
#
# ------------------------
# CORRELATION OF VIRAL LOAD OF RESPIRATORY PATHOGENS AND CO-INFECTIONS WITH DISEASE SEVERITY IN CHILDREN HOSPITALIZED FOR LOWER RESPIRATORY TRACT INFECTION
# ------------------------
#  Throughout this review, we highlight uses of sequence data and population genetics theory in studying pathogens as evolutionary model systems
#
#
#
# ------------------------
# BOCAVIRUS INFECTION IN OTHERWISE HEALTHY CHILDREN WITH RESPIRATORY DISEASE
# ------------------------
# Because genetics is a science of differences, a genetic analysis often requires phenotypic variability that is correlated with genetic variability
#
#
#
# ------------------------
# RESPIRATORY VIRAL INFECTIONS AND THE RISK OF RHEUMATOID ARTHRITIS
# ------------------------
# Similarities in the natural history and evolution of FIV and primate retroviruses indicate Africa as a common nexus
#
#
#
# ------------------------
# VIRAL INFECTION IN ADULTS WITH SEVERE ACUTE RESPIRATORY INFECTION IN COLOMBIA
# ------------------------
# Intra-host molecular evolution is also a feature of some PyV infections in humans
#
#
#
# ------------------------
# RESPIRATORY VIRAL INFECTIONS AND THE RISK OF RHEUMATOID ARTHRITIS
# ------------------------
#  Comparative studies in nonhuman species are invaluable and incorporate diverse disciplines such as genomics and wildlife biology with biomedical and veterinary science
#
#
#
# ------------------------
# RESPIRATORY VIRAL INFECTIONS AND THE RISK OF RHEUMATOID ARTHRITIS
# ------------------------
# The emergence of infectious disease within new host species or naïve populations can greatly influence species survival and adaptation
#
#
#
# ------------------------
# PREGNANCY AND INFECTION: USING DISEASE PATHOGENESIS TO INFORM VACCINE STRATEGY
# ------------------------
#  Interestingly, lion and FIV Ple variation revealed evidence of unsuspected genetic diversity even in the well-studied lion population of the Serengeti Ecosystem, which consists of recently admixed animals derived from three distinct genetic groups
#
#
#
# ------------------------
# COMPARING HUMAN METAPNEUMOVIRUS AND RESPIRATORY SYNCYTIAL VIRUS: VIRAL CO- DETECTIONS, GENOTYPES AND RISK FACTORS FOR SEVERE DISEASE
# ------------------------
#  Specific hosts impose specific evolutionary landscapes on viruses which will translate into signature genetic sequences
#
#
#
# ------------------------
# RESPIRATORY VIRAL INFECTIONS AND THE RISK OF RHEUMATOID ARTHRITIS
# ------------------------
#  Molecular genetic analyses of viral strains from African primates and felids show high levels of divergence consistent with long residence times
#
#
#
# ------------------------
# VIRUSES CAUSING LOWER RESPIRATORY SYMPTOMS IN YOUNG CHILDREN: FINDINGS FROM THE ORCHID BIRTH COHORT RESPIRATORY INFECTION
# ------------------------
#  Positive selection at IGHC genes across the mammal phylogeny and the presence/absence patterns of mammal IGHC genes
#
#
#
# ------------------------
# EMERGING INFECTIONS AND PREGNANCY: WEST NILE VIRUS, MONKEYPOX, SEVERE ACUTE RESPIRATORY SYNDROME, AND BIOTERRORISM
# ------------------------
# One of the oldest topics in genetics -natural selection for pathogen resistance -is being transformed by high-throughput biotechnology that offers unprecedented power to examine genome evolution

# %% [markdown]
# # TASK 4
# ## What do we know about vaccines and therapeutics? What has been published concerning research and development and evaluation efforts of vaccines and therapeutics?
# - Effectiveness of drugs being developed and tried to treat COVID-19 patients.
# - Clinical and bench trials to investigate less common viral inhibitors against COVID-19 such as naproxen, clarithromycin, and minocyclinethat that may exert effects on viral replication.
# - Methods evaluating potential complication of Antibody-Dependent Enhancement (ADE) in vaccine recipients.
# - Exploration of use of best animal models and their predictive value for a human vaccine.
# - Capabilities to discover a therapeutic (not vaccine) for the disease, and clinical effectiveness studies to discover therapeutics, to include antiviral agents.
# - Alternative models to aid decision makers in determining how to prioritize and distribute scarce, newly proven therapeutics as production ramps up. This could include identifying approaches for expanding production capacity to ensure equitable and timely distribution to populations in need.
# - Efforts targeted at a universal coronavirus vaccine.
# - Efforts to develop animal models and standardize challenge studies
# - Efforts to develop prophylaxis clinical studies and prioritize in healthcare workers
# - Approaches to evaluate risk for enhanced disease after vaccination
# - Assays to evaluate vaccine immune response and process development for vaccines, alongside suitable animal models

# %%
task = find_final_dataframe(4)
task
# Out:
#      0                                                  1  similarity
# 0   34   Influenza passive immunotherapy treatments in...    0.821997
# 1   23   Immunogenicity and protection efficacy of pol...    0.798728
# 2   23   Immunization with the polyvalent recombinant ...    0.792277
# 3   40   Hence combinations of multiple cytokines in a...    0.784590
# 4   15  Passive immunization with monoclonal antibodie...    0.782903
# 5    9   Chimeric and humanized antibodies have reduce...    0.769604
# 6   43   Although no dengue antibody therapeutics have...    0.768523
# 7    2   Rabbits vaccinated with SNV DNA vaccine with ...    0.759637
# 8    1   However, antibody therapies remain very costl...    0.758538
# 9   42  Proteases are proven therapeutic targets for a...    0.758465
# 10  34   Any additional benefits of influenzavaccinate...    0.753900
# 11  40   Another cancer therapeutic vaccine showed tha...    0.750085
# 12  41  Vaccine adjuvants trigger the innate immune sy...    0.748197
# 13  34   Vaccine induction or therapeutic production o...    0.747100
# 14  43  broadly neutralizing antibodies have the poten...    0.745390
# 15   1  The reticence for adopting mAb therapies again...    0.743988
# 16  26   Obvious targets for vaccine development have ...    0.743905
# 17  26  Breast cancer has been targeted in several the...    0.743902
# 18  27  Current strategies for the control of influenz...    0.740982
# 19  40  Vaccine adjuvants can be used to increase the ...    0.738267

# %%
read_result(task)
# Out:
# ------------------------
# POSTNATAL INFECTIONS AND IMMUNOLOGY AFFECTING CHRONIC LUNG DISEASE OF PREMATURITY
# ------------------------
#  Influenza passive immunotherapy treatments include use of convalescent plasma, hyperimmune immunoglobulins, or monoclonal antibody therapies
#
#
#
# ------------------------
# RISK FACTORS RELATED TO HEPATIC INJURY IN PATIENTS WITH CORONA VIRUS DISEASE 2019
# ------------------------
#  Immunogenicity and protection efficacy of polyvalent recombinant variola protein vaccines and polyvalent DNA vaccines expressing variola antigens
#
#
#
# ------------------------
# RISK FACTORS RELATED TO HEPATIC INJURY IN PATIENTS WITH CORONA VIRUS DISEASE 2019
# ------------------------
#  Immunization with the polyvalent recombinant VARV protein vaccines was significantly more immunogenic than immunization with the polyvalent VARV DNA vaccines (p<0
#
#
#
# ------------------------
# SEVERE LOWER RESPIRATORY TRACT INFECTION IN INFANTS AND TODDLERS FROM A NON-AFFLUENT POPULATION: VIRAL ETIOLOGY AND CO-DETECTION AS RISK FACTORS
# ------------------------
#  Hence combinations of multiple cytokines in a DNA vaccine formulation or sequential vaccination with cytokines may enhance vaccine efficacy
#
#
#
# ------------------------
# RESPIRATORY VIRAL INFECTIONS AND THE RISK OF RHEUMATOID ARTHRITIS
# ------------------------
# Passive immunization with monoclonal antibodies has several advantages over vaccination
#
#
#
# ------------------------
# STATINS MAY DECREASE THE FATALITY RATE OF MIDDLE EAST RESPIRATORY SYNDROME INFECTION
# ------------------------
#  Chimeric and humanized antibodies have reduced the risk of allergenicity from exposure to nonself antibodies and heightened the clinical effectiveness of MAb treatments
#
#
#
# ------------------------
# CLINICAL MANIFESTATIONS AND OUTCOMES OF RESPIRATORY SYNCYTIAL VIRUS INFECTION IN ADULT HOSPITALIZED PATIENTS
# ------------------------
#  Although no dengue antibody therapeutics have reached the stage of clinical trials, some of Antibody therapies for viral infections G Salazar et al
#
#
#
# ------------------------
# PREGNANCY AND PERINATAL OUTCOMES OF WOMEN WITH SEVERE ACUTE RESPIRATORY SYNDROME
# ------------------------
#  Rabbits vaccinated with SNV DNA vaccine with muscle electroporation (mEP) produced increased neutralizing antibody titers
#
#
#
# ------------------------
# EXERCISE AND INFECTION RISK
# ------------------------
#  However, antibody therapies remain very costly relative to antimicrobial drugs
#
#
#
# ------------------------
# INCIDENCE AND IMPLICATIONS OF UNRECOGNIZED VIRAL RESPIRATORY TRACT INFECTIONS IN PREMATURE INFANTS DURING THEIR BIRTH HOSPITALIZATION: A PROSPECTIVE SURVEILLANCE STUDY IN TWO NEONATAL INTENSIVE CARE UNITS NIH PUBLIC ACCESS
# ------------------------
# Proteases are proven therapeutic targets for antivirals
#
#
#
# ------------------------
# POSTNATAL INFECTIONS AND IMMUNOLOGY AFFECTING CHRONIC LUNG DISEASE OF PREMATURITY
# ------------------------
#  Any additional benefits of influenzavaccinated Tc bovine IVIG therapy compared to human IVIG therapeutics and bovine colostrum IgG therapeutics will need to be further assessed
#
#
#
# ------------------------
# SEVERE LOWER RESPIRATORY TRACT INFECTION IN INFANTS AND TODDLERS FROM A NON-AFFLUENT POPULATION: VIRAL ETIOLOGY AND CO-DETECTION AS RISK FACTORS
# ------------------------
#  Another cancer therapeutic vaccine showed that GM-CSF combined with shRNA knockdown of furin augmented vaccine efficacy [118]
#
#
#
# ------------------------
# IL-33 AND ST2 AS PREDICTORS OF DISEASE SEVERITY IN CHILDREN WITH VIRAL ACUTE LOWER RESPIRATORY INFECTION
# ------------------------
# Vaccine adjuvants trigger the innate immune system to enhance humoral and cellular responses to the coadministered vaccine antigens
#
#
#
# ------------------------
# POSTNATAL INFECTIONS AND IMMUNOLOGY AFFECTING CHRONIC LUNG DISEASE OF PREMATURITY
# ------------------------
#  Vaccine induction or therapeutic production of antibodies that target influenza internal proteins via ADCC response may prove to be a new development for influenza vaccine/treatment design
#
#
#
# ------------------------
# CLINICAL MANIFESTATIONS AND OUTCOMES OF RESPIRATORY SYNCYTIAL VIRUS INFECTION IN ADULT HOSPITALIZED PATIENTS
# ------------------------
# broadly neutralizing antibodies have the potential to be developed into therapeutics against dengue infections
#
#
#
# ------------------------
# EXERCISE AND INFECTION RISK
# ------------------------
# The reticence for adopting mAb therapies against infectious diseases is intriguing given that antibody therapies were the first effective antimicrobials
#
#
#
# ------------------------
# OBESITY AND RISK OF RESPIRATORY TRACT INFECTIONS: RESULTS OF AN INFECTION-DIARY BASED COHORT STUDY
# ------------------------
#  Obvious targets for vaccine development have been antigens of influenza virus and HIV
#
#
#
# ------------------------
# OBESITY AND RISK OF RESPIRATORY TRACT INFECTIONS: RESULTS OF AN INFECTION-DIARY BASED COHORT STUDY
# ------------------------
# Breast cancer has been targeted in several therapeutic and prophylactic vaccine studies
#
#
#
# ------------------------
# ESTIMATING THE RISKS FROM COVID-19 INFECTION IN ADULT CHEMOTHERAPY PATIENTS
# ------------------------
# Current strategies for the control of influenza include vaccination and antiviral drug treatment
#
#
#
# ------------------------
# SEVERE LOWER RESPIRATORY TRACT INFECTION IN INFANTS AND TODDLERS FROM A NON-AFFLUENT POPULATION: VIRAL ETIOLOGY AND CO-DETECTION AS RISK FACTORS
# ------------------------
# Vaccine adjuvants can be used to increase the immunogenicity of otherwise weakly immunogenic antigens

# %% [markdown]
# # TASK 5
# ## What has been published about medical care? What has been published concerning surge capacity and nursing homes? What has been published concerning efforts to inform allocation of scarce resources? What do we know about personal protective equipment? What has been published concerning alternative methods to advise on disease management? What has been published concerning processes of care? What do we know about the clinical characterization and management of the virus?
# - Resources to support skilled nursing facilities and long term care facilities.
# - Mobilization of surge medical staff to address shortages in overwhelmed communities
# - Age-adjusted mortality data for Acute Respiratory Distress Syndrome (ARDS) with/without other organ - failure – particularly for viral etiologies
# - Extracorporeal membrane oxygenation (ECMO) outcomes data of COVID-19 patients
# - Outcomes data for COVID-19 after mechanical ventilation adjusted for age.
# - Knowledge of the frequency, manifestations, and course of extrapulmonary manifestations of COVID-19, including, but not limited to, possible cardiomyopathy and cardiac arrest.
# - Application of regulatory standards (e.g., EUA, CLIA) and ability to adapt care to crisis standards of care level.
# - Approaches for encouraging and facilitating the production of elastomeric respirators, which can save thousands of N95 masks.
# - Best telemedicine practices, barriers and faciitators, and specific actions to remove/expand them within and across state boundaries.
# - Guidance on the simple things people can do at home to take care of sick people and manage disease.
# - Oral medications that might potentially work.
# - Use of AI in real-time health care delivery to evaluate interventions, risk factors, and outcomes in a way that could not be done manually.
# - Best practices and critical challenges and innovative solutions and technologies in hospital flow and organization, workforce protection, workforce allocation, community-based support resources, payment, and supply chain management to enhance capacity, efficiency, and outcomes.
# - Efforts to define the natural history of disease to inform clinical care, public health interventions, infection prevention control, transmission, and clinical trials
# - Efforts to develop a core clinical outcome set to maximize usability of data across a range of trials
# - Efforts to determine adjunctive and supportive interventions that can improve the clinical outcomes of infected patients (e.g. steroids, high flow oxygen)

# %%
task = find_final_dataframe(5)
task
# Out:
#      0                                                  1  similarity
# 0   32   Medical masks are not designed to provide res...    0.790719
# 1    1   Respirators are designed to provide respirato...    0.781719
# 2   36   NIOSH certifies respirators and develops reco...    0.777434
# 3   37  Advanced respiratory protective equipment (RPE...    0.769795
# 4   10   In certain clinical situations, however, pote...    0.759648
# 5    8  To compare the effectiveness of N95 respirator...    0.759275
# 6   32   There are gaps in knowledge about prevention ...    0.757752
# 7   11   Providing accurate information to HCWs and ho...    0.752134
# 8   35   Concerns over the protection of health care p...    0.751768
# 9   15   This study indicated that N95 respirators may...    0.746693
# 10  20  The use of personal protection equipment durin...    0.742942
# 11  14   Less than half of respondents reported compli...    0.742916
# 12  35   NIOSH investigators recommended the use of al...    0.742693
# 13  25   National Institute for Occupational Safety an...    0.742086
# 14  13   Investigations related to severe acute respir...    0.741474
# 15  36  The most commonly used type of respirator in h...    0.741105
# 16  25   The use of respiratory protective devices is ...    0.740771
# 17  13  Under the Cal/OSHA ATD standard, employers are...    0.739471
# 18  43  A shortage of respiratory protection devices d...    0.736632
# 19  19  Pandemics, outbreaks of emerging infectious di...    0.735588

# %%
read_result(task)
# Out:
# ------------------------
# A PROSPECTIVE STUDY OF RESPIRATORY VIRAL INFECTION IN PREGNANT WOMEN WITH AND WITHOUT ASTHMA
# ------------------------
#  Medical masks are not designed to provide respiratory protection
#
#
#
# ------------------------
# EXERCISE AND INFECTION RISK
# ------------------------
#  Respirators are designed to provide respiratory protection through filtration and fit, and properly fitted respirators provide better protection compared to medical masks
#
#
#
# ------------------------
# THE IMPACT OF RESPIRATORY VIRAL INFECTION ON WHEEZING ILLNESSES AND ASTHMA EXACERBATIONS
# ------------------------
#  NIOSH certifies respirators and develops recommendations on the use of respiratory protection in health care workplaces to protect workers
#
#
#
# ------------------------
# EMERGING INFECTIONS AND PREGNANCY: WEST NILE VIRUS, MONKEYPOX, SEVERE ACUTE RESPIRATORY SYNDROME, AND BIOTERRORISM
# ------------------------
# Advanced respiratory protective equipment (RPE), like powered air-purifying respirators and N95 respirators, are critical for protecting health care workers (HCWs) from contracting and spreading airborne infections
#
#
#
# ------------------------
# HUMAN METAPNEUMOVIRUS INFECTION IN JORDANIAN CHILDREN: EPIDEMIOLOGY AND RISK FACTORS FOR SEVERE DISEASE
# ------------------------
#  In certain clinical situations, however, potential exposure to airborne contaminants and infectious agents also necessitates the use of respiratory PPE, such as an N95 particulate filtering facepiece respirator (ie, surgical N95 respirator)
#
#
#
# ------------------------
# VIRUSES CAUSING LOWER RESPIRATORY SYMPTOMS IN YOUNG CHILDREN: FINDINGS FROM THE ORCHID BIRTH COHORT RESPIRATORY INFECTION
# ------------------------
# To compare the effectiveness of N95 respirators and medical masks at protecting HCP from acquiring viral respiratory illnesses in the workplace
#
#
#
# ------------------------
# A PROSPECTIVE STUDY OF RESPIRATORY VIRAL INFECTION IN PREGNANT WOMEN WITH AND WITHOUT ASTHMA
# ------------------------
#  There are gaps in knowledge about prevention of influenza by medical masks and respirators
#
#
#
# ------------------------
# RESPIRATORY VIRUS INFECTION AMONG HOSPITALIZED ADULT PATIENTS WITH OR WITHOUT CLINICALLY APPARENT RESPIRATORY INFECTION: A PROSPECTIVE COHORT STUDY
# ------------------------
#  Providing accurate information to HCWs and hospital respiratory protection program managers regarding the optimal respiratory protective equipment to employ when faced with outbreaks of severe respiratory pathogens will require additional research
#
#
#
# ------------------------
# DISEASE ASSOCIATED WITH EQUINE CORONAVIRUS INFECTION AND HIGH CASE FATALITY RATE
# ------------------------
#  Concerns over the protection of health care personnel performing these types of procedures on patients with H1N1 2009 infection led to recommendations for higher facepiece filtering devices, such as N95 respirators
#
#
#
# ------------------------
# RESPIRATORY VIRAL INFECTIONS AND THE RISK OF RHEUMATOID ARTHRITIS
# ------------------------
#  This study indicated that N95 respirators may not provide consistent protection against respiratory infection for HCWs
#
#
#
# ------------------------
# PREVALENCE OF VIRAL RESPIRATORY TRACT INFECTIONS IN CHILDREN WITH ASTHMA
# ------------------------
# The use of personal protection equipment during tracheal intubation of patients with infectious respiratory illnesses is essential for the safety of health care workers
#
#
#
# ------------------------
# THE INCIDENCE OF RESPIRATORY TRACT INFECTION IN ADULTS REQUIRING HOSPITALIZATION FOR ASTHMA*
# ------------------------
#  Less than half of respondents reported compliance with the recommended use of facial protection (eye/face protection, respirators, and surgical masks) to prevent occupational transmission of communicable respiratory disease
#
#
#
# ------------------------
# DISEASE ASSOCIATED WITH EQUINE CORONAVIRUS INFECTION AND HIGH CASE FATALITY RATE
# ------------------------
#  NIOSH investigators recommended the use of alternative infection control technologies, such as laminar airflow
#
#
#
# ------------------------
# EPIDEMIOLOGY OF SEVERE ACUTE RESPIRATORY ILLNESS AND RISK FACTORS FOR INFLUENZA INFECTION AND CLINICAL SEVERITY AMONG ADULTS IN MALAWI, 2011-2013
# ------------------------
#  National Institute for Occupational Safety and Health (NIOSH)-approved respirators are also recommended for protection of health care workers against several other pathogenic microorganisms including Mycobacterium tuberculosis, severe acute respiratory syndrome, Bacillus anthracis, and others
#
#
#
# ------------------------
# VIRAL RESPIRATORY INFECTIONS IN PRETERM INFANTS DURING AND AFTER HOSPITALIZATION
# ------------------------
#  Investigations related to severe acute respiratory syndrome outbreaks have identified difficulties achieving compliance with PPE policies, especially for respiratory and facial protection
#
#
#
# ------------------------
# THE IMPACT OF RESPIRATORY VIRAL INFECTION ON WHEEZING ILLNESSES AND ASTHMA EXACERBATIONS
# ------------------------
# The most commonly used type of respirator in health care settings are NIOSH certified N95 filtering facepiece respirators (FFRs)
#
#
#
# ------------------------
# EPIDEMIOLOGY OF SEVERE ACUTE RESPIRATORY ILLNESS AND RISK FACTORS FOR INFLUENZA INFECTION AND CLINICAL SEVERITY AMONG ADULTS IN MALAWI, 2011-2013
# ------------------------
#  The use of respiratory protective devices is one intervention designed to reduce exposure to infectious influenza aerosols
#
#
#
# ------------------------
# VIRAL RESPIRATORY INFECTIONS IN PRETERM INFANTS DURING AND AFTER HOSPITALIZATION
# ------------------------
# Under the Cal/OSHA ATD standard, employers are required to implement infection control practices, including the use of respiratory protection for aerosol transmissible infectious pathogens
#
#
#
# ------------------------
# CLINICAL MANIFESTATIONS AND OUTCOMES OF RESPIRATORY SYNCYTIAL VIRUS INFECTION IN ADULT HOSPITALIZED PATIENTS
# ------------------------
# A shortage of respiratory protection devices during pandemic diseases is possible
#
#
#
# ------------------------
# DOES AN UPPER RESPIRATORY TRACT INFECTION DURING PREGNANCY AFFECT PERINATAL OUTCOMES? A LITERATURE REVIEW
# ------------------------
# Pandemics, outbreaks of emerging infectious diseases, and bioterrorism attacks may necessitate long-term filtering face piece respirator (N95) use for health care personnel

# %% [markdown]
# # TASK 6
# ## What do we know about the effectiveness of non-pharmaceutical interventions? What is known about equity and barriers to compliance for non-pharmaceutical interventions?
# - Guidance on ways to scale up NPIs in a more coordinated way (e.g., establish funding, infrastructure and authorities to support real time, authoritative (qualified participants) collaboration with all states to gain consensus on consistent guidance and to mobilize resources to geographic areas where critical shortfalls are identified) to give us time to enhance our health care delivery system capacity to respond to an increase in cases.
# - Rapid design and execution of experiments to examine and compare NPIs currently being implemented. DHS Centers for Excellence could potentially be leveraged to conduct these experiments.
# - Rapid assessment of the likely efficacy of school closures, travel bans, bans on mass gatherings of various sizes, and other social distancing approaches.
# - Methods to control the spread in communities, barriers to compliance and how these vary among different populations..
# - Models of potential interventions to predict costs and benefits that take account of such factors as race, income, disability, age, geographic location, immigration status, housing status, employment status, and health insurance status.
# - Policy changes necessary to enable the compliance of individuals with limited resources and the underserved with NPIs.
# - Research on why people fail to comply with public health advice, even if they want to do so (e.g., social or financial costs may be too high).
# - Research on the economic impact of this or any pandemic. This would include identifying policy and programmatic alternatives that lessen/mitigate risks to critical government services, food distribution and supplies, access to critical household supplies, and access to health diagnoses, treatment, and needed care, regardless of ability to pay.

# %%
task = find_final_dataframe(6)
task
# Out:
#      0                                                  1  similarity
# 0   32  Although wholesalers had declared they would h...    0.734434
# 1    6   combining quarantine and isolation policies w...    0.732868
# 2   23   For high/ medium impact medicinal products, t...    0.706193
# 3   32   Questions were addressing aspects related to ...    0.695763
# 4   16  While other mitigation strategies (eg, vaccina...    0.695088
# 5    1   New and challenging risks can be introduced d...    0.686111
# 6   23   On the other side, the Italian regulatory fra...    0.683666
# 7   27   Background: Economic pressures and legal cons...    0.682635
# 8   32   During a 7-day closure, all stakeholders desc...    0.681922
# 9    6   Some evidence suggests that restricting mass ...    0.679371
# 10   6   This is particularly important given the need...    0.676327
# 11  35   Key scientific and policy issues are highligh...    0.676226
# 12  32   While current Vietnam government regulations ...    0.675585
# 13  23   Consequently, several European countries incl...    0.675474
# 14   1   Some consider using alcohol-containing produc...    0.675040
# 15  18   5, 22 Might animal protection organizations j...    0.673933
# 16  46  ,Although mitigation strategy including school...    0.673757
# 17   6  In summary, there is some evidence that when a...    0.672764
# 18   0   Three enhanced surveillance activities for ma...    0.672727
# 19  41   These are often carried out in cooperation wi...    0.672200

# %%
read_result(task)
# Out:
# ------------------------
# A PROSPECTIVE STUDY OF RESPIRATORY VIRAL INFECTION IN PREGNANT WOMEN WITH AND WITHOUT ASTHMA
# ------------------------
# Although wholesalers had declared they would halt poultry operations during both 7-and 21-day market closures, further inquiry revealed that they disagreed with compulsory culling of poultry associated with market closures in case of market closures as specified in the Vietnam action plan
#
#
#
# ------------------------
# CLINICAL CHARACTERISTICS AND OUTCOMES OF RESPIRATORY SYNCYTIAL VIRUS INFECTION IN PREGNANT WOMEN
# ------------------------
#  combining quarantine and isolation policies with banning mass gatherings
#
#
#
# ------------------------
# RISK FACTORS RELATED TO HEPATIC INJURY IN PATIENTS WITH CORONA VIRUS DISEASE 2019
# ------------------------
#  For high/ medium impact medicinal products, the importation should be allowed during an ongoing shortage
#
#
#
# ------------------------
# A PROSPECTIVE STUDY OF RESPIRATORY VIRAL INFECTION IN PREGNANT WOMEN WITH AND WITHOUT ASTHMA
# ------------------------
#  Questions were addressing aspects related to market closures such as reaction of stakeholders, impact of market closure on the livelihoods, other trading options for poultry in case of market closure, reaction on compulsory culling of poultry, and willingness of stakeholders to collaborate and under which conditions traders would comply with government policy on market closure
#
#
#
# ------------------------
# VIRAL INFECTION IN ADULTS WITH SEVERE ACUTE RESPIRATORY INFECTION IN COLOMBIA
# ------------------------
# While other mitigation strategies (eg, vaccination and antivirals) may accompany school closures, there are many situations in which school closures may be the only major intervention option
#
#
#
# ------------------------
# EXERCISE AND INFECTION RISK
# ------------------------
#  New and challenging risks can be introduced during mass gatherings
#
#
#
# ------------------------
# RISK FACTORS RELATED TO HEPATIC INJURY IN PATIENTS WITH CORONA VIRUS DISEASE 2019
# ------------------------
#  On the other side, the Italian regulatory framework has been updated to permit AIFA to impose temporary blockage of exportations to prevent or mitigate drug shortages or unavailability of a medicinal product authorized in Italy (Art
#
#
#
# ------------------------
# ESTIMATING THE RISKS FROM COVID-19 INFECTION IN ADULT CHEMOTHERAPY PATIENTS
# ------------------------
#  Background: Economic pressures and legal constraints increasingly force hospital pharmacies to purchase generic drugs rather than original branded products
#
#
#
# ------------------------
# A PROSPECTIVE STUDY OF RESPIRATORY VIRAL INFECTION IN PREGNANT WOMEN WITH AND WITHOUT ASTHMA
# ------------------------
#  During a 7-day closure, all stakeholders described how they would adapt by shifting market operations to other locations, but during closure of minimum 21 days, all stakeholders reported that they would halt trading operations
#
#
#
# ------------------------
# CLINICAL CHARACTERISTICS AND OUTCOMES OF RESPIRATORY SYNCYTIAL VIRUS INFECTION IN PREGNANT WOMEN
# ------------------------
#  Some evidence suggests that restricting mass gatherings together with other social distancing measures may help to reduce transmission
#
#
#
# ------------------------
# CLINICAL CHARACTERISTICS AND OUTCOMES OF RESPIRATORY SYNCYTIAL VIRUS INFECTION IN PREGNANT WOMEN
# ------------------------
#  This is particularly important given the need to weigh any potential benefits against the economic and social disruption that banning or restricting mass gatherings could have on society
#
#
#
# ------------------------
# DISEASE ASSOCIATED WITH EQUINE CORONAVIRUS INFECTION AND HIGH CASE FATALITY RATE
# ------------------------
#  Key scientific and policy issues are highlighted along with considerations for policy makers to weigh when making decisions on whether to recommend extended use and/or limited reuse of FFRs during routine health care situations and for public health emergencies involving respiratory pathogens that have the potential for aerosol transmission
#
#
#
# ------------------------
# A PROSPECTIVE STUDY OF RESPIRATORY VIRAL INFECTION IN PREGNANT WOMEN WITH AND WITHOUT ASTHMA
# ------------------------
#  While current Vietnam government regulations do foresee financial compensation for compulsory culling of poultry at farms, there is at present no provision for compensation for poultry culled at markets
#
#
#
# ------------------------
# RISK FACTORS RELATED TO HEPATIC INJURY IN PATIENTS WITH CORONA VIRUS DISEASE 2019
# ------------------------
#  Consequently, several European countries included specific restrictions of the product exportation to preserve the National stockpiles during shortages in their regulatory frameworks (Bochenek et al
#
#
#
# ------------------------
# EXERCISE AND INFECTION RISK
# ------------------------
#  Some consider using alcohol-containing products (eg, hand sanitizers) as prohibited during Hajj ritual too, although recently religious scholars have allowed the use of alcohol for medical purposes
#
#
#
# ------------------------
# PREVENTING RESPIRATORY SYNCYTIAL VIRUS INFECTIONS IN HOSPITALIZED CHILDREN AND ADULTS: SHOULD WE DO BETTER? INFECTION PREVENTION IN PRACTICE
# ------------------------
#  5, 22 Might animal protection organizations join public health colleagues to forge a public campaign against the keeping of exotic animals as pets and for entertainment? Public health agencies and animal protection organizations should work with policymakers to enact restrictions on wildlife importation
#
#
#
# ------------------------
# UNRECOGNIZED VIRAL RESPIRATORY TRACT INFECTIONS IN PREMATURE INFANTS DURING THEIR BIRTH HOSPITALIZATION: A PROSPECTIVE SURVEILLANCE STUDY IN TWO NEONATAL INTENSIVE CARE UNITS
# ------------------------
# ,Although mitigation strategy including school closure involves multiple public health objectives (e
#
#
#
# ------------------------
# CLINICAL CHARACTERISTICS AND OUTCOMES OF RESPIRATORY SYNCYTIAL VIRUS INFECTION IN PREGNANT WOMEN
# ------------------------
# In summary, there is some evidence that when applied early and in tandem with other public health measures, such as isolation and quarantine and closures of educational institutions, mass gathering restrictions may help in reducing transmission
#
#
#
# ------------------------
# RESPIRATORY DISEASE IN PREGNANCY
# ------------------------
#  Three enhanced surveillance activities for mass gathering events in PICTs occurred during national or regional disease outbreaks that had the potential to severely affect the mass gatherings, place greater strain on health services, and cause substantial tourismrelated economic and reputation loss
#
#
#
# ------------------------
# IL-33 AND ST2 AS PREDICTORS OF DISEASE SEVERITY IN CHILDREN WITH VIRAL ACUTE LOWER RESPIRATORY INFECTION
# ------------------------
#  These are often carried out in cooperation with pharmaceutical companies due to the high costs associated with testing large groups of patients and expensive registration procedures

# %% [markdown]
# # TASK 7
# ## What do we know about diagnostics and surveillance? What has been published concerning systematic, holistic approach to diagnostics (from the public health surveillance perspective to being able to predict clinical outcomes)?
# - How widespread current exposure is to be able to make immediate policy recommendations on mitigation measures. Denominators for testing and a mechanism for rapidly sharing that information, including demographics, to the extent possible. Sampling methods to determine asymptomatic disease (e.g., use of serosurveys (such as convalescent samples) and early detection of disease (e.g., use of screening of neutralizing antibodies such as ELISAs).
# - Efforts to increase capacity on existing diagnostic platforms and tap into existing surveillance platforms.
# - Recruitment, support, and coordination of local expertise and capacity (public, private—commercial, and non-profit, including academic), including legal, ethical, communications, and operational issues.
# - National guidance and guidelines about best practices to states (e.g., how states might leverage universities and private laboratories for testing purposes, communications to public health officials and the public).
# - Development of a point-of-care test (like a rapid influenza test) and rapid bed-side tests, recognizing the tradeoffs between speed, accessibility, and accuracy.
# Rapid design and execution of targeted surveillance experiments calling for all potential testers using PCR in a defined area to start testing and report to a specific entity. These experiments could aid in collecting longitudinal samples, which are critical to understanding the impact of ad hoc local interventions (which also need to be recorded).
# - Separation of assay development issues from instruments, and the role of the private sector to help quickly migrate assays onto those devices.
# - Efforts to track the evolution of the virus (i.e., genetic drift or mutations) and avoid locking into specific reagents and surveillance/detection schemes.
# - Latency issues and when there is sufficient viral load to detect the pathogen, and understanding of what is needed in terms of biological and environmental sampling.
# - Use of diagnostics such as host response markers (e.g., cytokines) to detect early disease or predict severe disease progression, which would be important to understanding best clinical practice and efficacy of therapeutic interventions.
# - Policies and protocols for screening and testing.
# - Policies to mitigate the effects on supplies associated with mass testing, including swabs and reagents.
# - Technology roadmap for diagnostics.
# - Barriers to developing and scaling up new diagnostic tests (e.g., market forces), how future coalition and accelerator models (e.g., Coalition for Epidemic Preparedness Innovations) could provide critical funding for diagnostics, and opportunities for a streamlined regulatory environment.
# - New platforms and technology (e.g., CRISPR) to improve response times and employ more holistic approaches to COVID-19 and future diseases.
# - Coupling genomics and diagnostic testing on a large scale.
# - Enhance capabilities for rapid sequencing and bioinformatics to target regions of the genome that will allow specificity for a particular variant.
# Enhance capacity (people, technology, data) for sequencing with advanced analytics for unknown pathogens, and explore capabilities for distinguishing naturally-occurring pathogens from intentional.
# - One Health surveillance of humans and potential sources of future spillover or ongoing exposure for this organism and future pathogens, including both evolutionary hosts (e.g., bats) and transmission hosts (e.g., heavily trafficked and farmed wildlife and domestic food and companion species), inclusive of environmental, demographic, and occupational risk factors.

# %%
task = find_final_dataframe(7)
task
# Out:
#      0                                                  1  similarity
# 0   48   This move centralized DoD-wide healthcare sur...    0.802253
# 1    2  Syndromic surveillance often involves automate...    0.778376
# 2    7   Use of existing CDC LRN PHEP-funded systems e...    0.776436
# 3    5      Assessing alternative surveillance strategies    0.772046
# 4   29   These smart health monitoring systems automat...    0.767059
# 5    0   68 These studies show potential applications ...    0.762383
# 6    7   Develop and deploy novel diagnostics and stre...    0.759751
# 7   13  The results of this Delphi survey suggest that...    0.759531
# 8   32  We reconstituted a surveillance system in soft...    0.759209
# 9   32  Most automated surveillance systems utilize di...    0.754501
# 10  13   Establishing and maintaining surveillance sys...    0.752590
# 11  39   Internet surveillance of healthcare usage can...    0.752308
# 12  15   Standard infectious disease surveillance meth...    0.750713
# 13  19   Biosurveillance activities range from standar...    0.750589
# 14  30   Invest in surveillance workforce development ...    0.749042
# 15   0  The potential for internet-based surveillance ...    0.748056
# 16  32   Our results further argue that diagnostic cod...    0.748049
# 17  27   This study is aimed at designing and examinin...    0.747943
# 18  10   Ideally, such systems operate automatically a...    0.747316
# 19   0   A global response requires concerted internat...    0.746831

# %%
read_result(task)
# Out:
# ------------------------
# VIRAL ETIOLOGIES OF HOSPITALIZED ACUTE LOWER RESPIRATORY INFECTION PATIENTS IN CHINA
# ------------------------
#  This move centralized DoD-wide healthcare surveillance initiatives with domestic and overseas laboratory surveillance efforts
#
#
#
# ------------------------
# PREGNANCY AND PERINATAL OUTCOMES OF WOMEN WITH SEVERE ACUTE RESPIRATORY SYNDROME
# ------------------------
# Syndromic surveillance often involves automated electronic reporting and statistical algorithms that sometimes require a complex information technology infrastructure
#
#
#
# ------------------------
# RISK OF MORTALITY ASSOCIATED WITH RESPIRATORY SYNCYTIAL VIRUS AND INFLUENZA INFECTION IN ADULTS
# ------------------------
#  Use of existing CDC LRN PHEP-funded systems enabled rapid and effective communication between clinical laboratories and public health laboratories
#
#
#
# ------------------------
# RISK FACTORS FOR SEVERE BRONCHIOLITIS CAUSED BY RESPIRATORY VIRUS INFECTIONS AMONG MEXICAN CHILDREN IN AN EMERGENCY DEPARTMENT
# ------------------------
# Assessing alternative surveillance strategies
#
#
#
# ------------------------
# COMPARING HUMAN METAPNEUMOVIRUS AND RESPIRATORY SYNCYTIAL VIRUS: VIRAL CO- DETECTIONS, GENOTYPES AND RISK FACTORS FOR SEVERE DISEASE
# ------------------------
#  These smart health monitoring systems automate patient monitoring tasks and facilitate workflow management
#
#
#
# ------------------------
# RESPIRATORY DISEASE IN PREGNANCY
# ------------------------
#  68 These studies show potential applications of internet-based surveillance systems in bolstering traditional surveillance system capacity and guiding public health action
#
#
#
# ------------------------
# RISK OF MORTALITY ASSOCIATED WITH RESPIRATORY SYNCYTIAL VIRUS AND INFLUENZA INFECTION IN ADULTS
# ------------------------
#  Develop and deploy novel diagnostics and strengthen laboratory systems
#
#
#
# ------------------------
# VIRAL RESPIRATORY INFECTIONS IN PRETERM INFANTS DURING AND AFTER HOSPITALIZATION
# ------------------------
# The results of this Delphi survey suggest that there is broad support for using event-based social media monitoring and pathogen WGS technologies to enhance communicable disease surveillance systems across sectoral groups and relevant policy networks
#
#
#
# ------------------------
# A PROSPECTIVE STUDY OF RESPIRATORY VIRAL INFECTION IN PREGNANT WOMEN WITH AND WITHOUT ASTHMA
# ------------------------
# We reconstituted a surveillance system in software to evaluate the impact of alternative EMR-enabled case-detection approaches on outbreak detection
#
#
#
# ------------------------
# A PROSPECTIVE STUDY OF RESPIRATORY VIRAL INFECTION IN PREGNANT WOMEN WITH AND WITHOUT ASTHMA
# ------------------------
# Most automated surveillance systems utilize diagnostic codes to find diseased individuals
#
#
#
# ------------------------
# VIRAL RESPIRATORY INFECTIONS IN PRETERM INFANTS DURING AND AFTER HOSPITALIZATION
# ------------------------
#  Establishing and maintaining surveillance systems are the foundation of effective outbreak detection and public health response
#
#
#
# ------------------------
# CLINICAL CHARACTERISTICS AND OUTCOME OF RESPIRATORY SYNCYTIAL VIRUS INFECTION AMONG ADULTS HOSPITALIZED WITH INFLUENZA-LIKE ILLNESS IN FRANCE
# ------------------------
#  Internet surveillance of healthcare usage can be used to complement traditional surveillance
#
#
#
# ------------------------
# RESPIRATORY VIRAL INFECTIONS AND THE RISK OF RHEUMATOID ARTHRITIS
# ------------------------
#  Standard infectious disease surveillance methodologies have been derived from indicator-based surveillance and event-based surveillance
#
#
#
# ------------------------
# DOES AN UPPER RESPIRATORY TRACT INFECTION DURING PREGNANCY AFFECT PERINATAL OUTCOMES? A LITERATURE REVIEW
# ------------------------
#  Biosurveillance activities range from standard epidemiological practices to advanced technological systems, utilizing complex algorithms [13]
#
#
#
# ------------------------
# OUTCOME RISK FACTORS DURING RESPIRATORY INFECTIONS IN A PAEDIATRIC WARD IN ANTANANARIVO
# ------------------------
#  Invest in surveillance workforce development to build competencies and improve organizational capacity to utilize technological advances in surveillance practice
#
#
#
# ------------------------
# RESPIRATORY DISEASE IN PREGNANCY
# ------------------------
# The potential for internet-based surveillance systems to revolutionise emerging infectious disease surveillance was shown by Scarpino and colleagues
#
#
#
# ------------------------
# A PROSPECTIVE STUDY OF RESPIRATORY VIRAL INFECTION IN PREGNANT WOMEN WITH AND WITHOUT ASTHMA
# ------------------------
#  Our results further argue that diagnostic codes sets used for case-detection should routinely optimized during surveillance system development or expansion
#
#
#
# ------------------------
# ESTIMATING THE RISKS FROM COVID-19 INFECTION IN ADULT CHEMOTHERAPY PATIENTS
# ------------------------
#  This study is aimed at designing and examining automatic online news monitoring and classification methods for syndromic surveillance and global situational awareness
#
#
#
# ------------------------
# HUMAN METAPNEUMOVIRUS INFECTION IN JORDANIAN CHILDREN: EPIDEMIOLOGY AND RISK FACTORS FOR SEVERE DISEASE
# ------------------------
#  Ideally, such systems operate automatically and include sensitive and specific statistical surveillance software and alerting systems
#
#
#
# ------------------------
# RESPIRATORY DISEASE IN PREGNANCY
# ------------------------
#  A global response requires concerted international approaches to strengthen the capacity of emerging infectious diseases surveillance systems worldwide

# %% [markdown]
# # TASK 9
# ## What has been published concerning ethical considerations for research? What has been published concerning social sciences at the outbreak response?
# - Efforts to articulate and translate existing ethical principles and standards to salient issues in COVID-2019
# - Efforts to embed ethics across all thematic areas, engage with novel ethical issues that arise and coordinate to minimize duplication of oversight
# - Efforts to support sustained education, access, and capacity building in the area of ethics
# - Efforts to establish a team at WHO that will be integrated within multidisciplinary research and operational platforms and that will connect with existing and expanded global networks of social sciences.
# - Efforts to develop qualitative assessment frameworks to systematically collect information related to local barriers and enablers for the uptake and adherence to public health measures for prevention and control. This includes the rapid identification of the secondary impacts of these measures. (e.g. use of surgical masks, modification of health seeking behaviors for SRH, school closures)
# - Efforts to identify how the burden of responding to the outbreak and implementing public health measures affects the physical and psychological health of those providing care for Covid-19 patients and identify the immediate needs that must be addressed.
# - Efforts to identify the underlying drivers of fear, anxiety and stigma that fuel misinformation and rumor, particularly through social media.

# %%
task = find_final_dataframe(9)
task
# Out:
#      0                                                  1  similarity
# 0   25   It also provides resources on how social dete...    0.863825
# 1    1   The purpose of this study is to investigate h...    0.862497
# 2    0   This study explored the possibility of utiliz...    0.861145
# 3    1   In this respect, this study has identified gu...    0.860793
# 4   15   Future research agenda may focus on the socia...    0.858245
# 5    1   Taken together, these efforts facilitate sust...    0.857738
# 6   25   The presence of social programs in other sect...    0.855996
# 7    1  This study examined the factors that influence...    0.851541
# 8   40  There are also many existing studies on the so...    0.849750
# 9    8   80 Ethical dilemmas informing policy response...    0.849656
# 10  44   High-end technology transfer without developm...    0.849085
# 11   1  Perceptions of trust in the government's socia...    0.848286
# 12  32  Health authorities who intend to use content f...    0.846099
# 13   1  By integrating trust and health risk informati...    0.845532
# 14  44   Member university presidents have also begun ...    0.844909
# 15  44   Under conditions requiring social participati...    0.843894
# 16  43  Some good examples of Chinese initiatives in g...    0.843078
# 17   1  Information-communication technology (ICT) can...    0.842973
# 18   4   SNS social dependency is regarded as people's...    0.841900
# 19  20   Increasing numbers of public health departmen...    0.841508

# %%
read_result(task)
# Out:
# ------------------------
# EPIDEMIOLOGY OF SEVERE ACUTE RESPIRATORY ILLNESS AND RISK FACTORS FOR INFLUENZA INFECTION AND CLINICAL SEVERITY AMONG ADULTS IN MALAWI, 2011-2013
# ------------------------
#  It also provides resources on how social determinants of health such as poverty and social exclusion affect access to physical activity
#
#
#
# ------------------------
# EXERCISE AND INFECTION RISK
# ------------------------
#  The purpose of this study is to investigate how to increase government accountability for motivating citizens to engage in ICT-based health risk communication, thereby attaining sustainable public health practices through collaborative governance
#
#
#
# ------------------------
# RESPIRATORY DISEASE IN PREGNANCY
# ------------------------
#  This study explored the possibility of utilizing social media to monitor public perceptions on healthcare services
#
#
#
# ------------------------
# EXERCISE AND INFECTION RISK
# ------------------------
#  In this respect, this study has identified guiding principles and determining factors behind both government' and citizens' involvement in sustainable public health governance using ICT systems, specifically government social media sites used for health risk communication services
#
#
#
# ------------------------
# RESPIRATORY VIRAL INFECTIONS AND THE RISK OF RHEUMATOID ARTHRITIS
# ------------------------
#  Future research agenda may focus on the social-mediated crisis communication from perspectives of NPOs and provide theoretical and practical suggestions to increase organizational transparency and accountability in crises
#
#
#
# ------------------------
# EXERCISE AND INFECTION RISK
# ------------------------
#  Taken together, these efforts facilitate sustainable public health practices in the social media-based public governance era
#
#
#
# ------------------------
# EPIDEMIOLOGY OF SEVERE ACUTE RESPIRATORY ILLNESS AND RISK FACTORS FOR INFLUENZA INFECTION AND CLINICAL SEVERITY AMONG ADULTS IN MALAWI, 2011-2013
# ------------------------
#  The presence of social programs in other sectors does not reduce public health's obligation or commitment to addressing the social determinants of health
#
#
#
# ------------------------
# EXERCISE AND INFECTION RISK
# ------------------------
# This study examined the factors that influence citizens' likelihood of using government social media resources in the context of public health communication
#
#
#
# ------------------------
# SEVERE LOWER RESPIRATORY TRACT INFECTION IN INFANTS AND TODDLERS FROM A NON-AFFLUENT POPULATION: VIRAL ETIOLOGY AND CO-DETECTION AS RISK FACTORS
# ------------------------
# There are also many existing studies on the social interaction, social conflict, and social impact of public opinion analysis
#
#
#
# ------------------------
# VIRUSES CAUSING LOWER RESPIRATORY SYMPTOMS IN YOUNG CHILDREN: FINDINGS FROM THE ORCHID BIRTH COHORT RESPIRATORY INFECTION
# ------------------------
#  80 Ethical dilemmas informing policy response to the epidemic Within a public health emergency, values defined by public health ethics -an overriding priority afforded to "greater good" considerations 57,81 -should take precedence over individual concerns, according to ethicist Dawson
#
#
#
# ------------------------
# BOCAVIRUS INFECTION IN OTHERWISE HEALTHY CHILDREN WITH RESPIRATORY DISEASE
# ------------------------
#  High-end technology transfer without development in health infrastructures and basic social needs can be counterproductive without equity and distributional aspects of health policy
#
#
#
# ------------------------
# EXERCISE AND INFECTION RISK
# ------------------------
# Perceptions of trust in the government's social media sites were operationalized as credibility and integrity of its social media services
#
#
#
# ------------------------
# A PROSPECTIVE STUDY OF RESPIRATORY VIRAL INFECTION IN PREGNANT WOMEN WITH AND WITHOUT ASTHMA
# ------------------------
# Health authorities who intend to use content from social media and other Internet data also need to consider protection and privacy, such as legal and ethical implications related to using Internet and social media data for public health surveillance
#
#
#
# ------------------------
# EXERCISE AND INFECTION RISK
# ------------------------
# By integrating trust and health risk information into the e-government adoption model (GAM), this research examines factors that influence citizens' likelihood of using government social media resources
#
#
#
# ------------------------
# BOCAVIRUS INFECTION IN OTHERWISE HEALTHY CHILDREN WITH RESPIRATORY DISEASE
# ------------------------
#  Member university presidents have also begun to use APACPH networks and the Global Health Conferences to foster the social responsibility of universities whether in indigenous health, urbanization, or MDG-related goals
#
#
#
# ------------------------
# BOCAVIRUS INFECTION IN OTHERWISE HEALTHY CHILDREN WITH RESPIRATORY DISEASE
# ------------------------
#  Under conditions requiring social participation and reform, south involvement and leadership in human resource development is essential
#
#
#
# ------------------------
# CLINICAL MANIFESTATIONS AND OUTCOMES OF RESPIRATORY SYNCYTIAL VIRUS INFECTION IN ADULT HOSPITALIZED PATIENTS
# ------------------------
# Some good examples of Chinese initiatives in global health need further assessment including the use the new partnership in optimizing institutional governance, organizational structure, social and environmental benefits towards social cohesion, healthy life and living, wellbeing of all citizens and sustainable development at all levels
#
#
#
# ------------------------
# EXERCISE AND INFECTION RISK
# ------------------------
# Information-communication technology (ICT) can help governments and their citizens collaborate toward achieving sustainable public health practices
#
#
#
# ------------------------
# CLINICAL PRESENTATION AND BIRTH OUTCOMES ASSOCIATED WITH RESPIRATORY SYNCYTIAL VIRUS INFECTION IN PREGNANCY
# ------------------------
#  SNS social dependency is regarded as people's tendencies to depend on SNSs to gain social interactive gratification through interpersonal communication (Ha et al
#
#
#
# ------------------------
# PREVALENCE OF VIRAL RESPIRATORY TRACT INFECTIONS IN CHILDREN WITH ASTHMA
# ------------------------
#  Increasing numbers of public health departments and individuals are using social media platforms to communicate and share information during public health emergencies

# %% [markdown]
# # TASK 10
# ## What has been published about information sharing and inter-sectoral collaboration? What has been published about data standards and nomenclature? What has been published about governmental public health? What do we know about risk communication? What has been published about communicating with high-risk populations? What has been published to clarify community measures? What has been published about equity considerations and problems of inequity?
# - Methods for coordinating data-gathering with standardized nomenclature.
# - Sharing response information among planners, providers, and others.
# - Understanding and mitigating barriers to information-sharing.
# - How to recruit, support, and coordinate local (non-Federal) expertise and capacity relevant to public health emergency response (public, private, commercial and non-profit, including academic).
# - Integration of federal/state/local public health surveillance systems.
# - Value of investments in baseline public health response infrastructure preparedness
# - Modes of communicating with target high-risk populations (elderly, health care workers).
# - Risk communication and guidelines that are easy to understand and follow (include targeting at risk populations’ families too).
# - Communication that indicates potential risk of disease to all population groups.
# - Misunderstanding around containment and mitigation.
# - Action plan to mitigate gaps and problems of inequity in the Nation’s public health capability, capacity, and funding to ensure all citizens in need are supported and can access information, surveillance, and treatment.
# - Measures to reach marginalized and disadvantaged populations.
# - Data systems and research priorities and agendas incorporate attention to the needs and circumstances of disadvantaged populations and underrepresented minorities.
# - Mitigating threats to incarcerated people from COVID-19, assuring access to information, prevention, diagnosis, and treatment.
# - Understanding coverage policies (barriers and opportunities) related to testing, treatment, and care

# %%
task = find_final_dataframe(10)
task
# Out:
#      0                                                  1  similarity
# 0   18  The Laboratory Response NetworkThe creation of...    0.801619
# 1    6   Policy documents from government and related ...    0.797344
# 2    5  We sought public documents that detailed a pH1...    0.786898
# 3   22   This move centralized DoD-wide healthcare sur...    0.785675
# 4    6  For the purposes of this study, we included pr...    0.784919
# 5    6  Provincial government and regional health auth...    0.783257
# 6   27   Given that the politics of American anti-stat...    0.779710
# 7    2  Most states can successfully conduct public he...    0.777888
# 8   38   Laws, regulations, and policy bases of health...    0.776179
# 9   11   Data on such indicators are reported by healt...    0.775855
# 10  49   They report on a case study of public mental ...    0.775521
# 11  38   Laws, regulations and policy bases for health...    0.774740
# 12  11   In 2005, the WHO established international he...    0.773072
# 13  27   Cyber intelligence and disease surveillance a...    0.772006
# 14   5   Primary documents included: guidance document...    0.770871
# 15  27   31(p83) Proposals for the federal government ...    0.770595
# 16  27   The PHS appointed epidemiologists to serve in...    0.769865
# 17   9   A review of the pandemic plans of the Public ...    0.769689
# 18   0   The IHR cannot effectively govern global heal...    0.768803
# 19   5  This policy analysis used a multiple case stud...    0.768672

# %%
read_result(task)
# Out:
# ------------------------
# PREVENTING RESPIRATORY SYNCYTIAL VIRUS INFECTIONS IN HOSPITALIZED CHILDREN AND ADULTS: SHOULD WE DO BETTER? INFECTION PREVENTION IN PRACTICE
# ------------------------
# The Laboratory Response NetworkThe creation of the LRN stemmed from Presidential Decision Directive 39, which outlined antiterrorism policies and missions for federal departments and agencies
#
#
#
# ------------------------
# CLINICAL CHARACTERISTICS AND OUTCOMES OF RESPIRATORY SYNCYTIAL VIRUS INFECTION IN PREGNANT WOMEN
# ------------------------
#  Policy documents from government and related public health organizations in both provinces have identified similar key issues in planning the public health workforce
#
#
#
# ------------------------
# RISK FACTORS FOR SEVERE BRONCHIOLITIS CAUSED BY RESPIRATORY VIRUS INFECTIONS AMONG MEXICAN CHILDREN IN AN EMERGENCY DEPARTMENT
# ------------------------
# We sought public documents that detailed a pH1N1 policy recommendation related to the four policies
#
#
#
# ------------------------
# HOSPITAL-ACQUIRED RESPIRATORY VIRAL INFECTIONS: INCIDENCE, MORBIDITY, AND MORTALITY IN PEDIATRIC AND ADULT PATIENTS
# ------------------------
#  This move centralized DoD-wide healthcare surveillance initiatives with domestic and overseas laboratory surveillance efforts
#
#
#
# ------------------------
# CLINICAL CHARACTERISTICS AND OUTCOMES OF RESPIRATORY SYNCYTIAL VIRUS INFECTION IN PREGNANT WOMEN
# ------------------------
# For the purposes of this study, we included provincial government and select public health organizations' policy and planning documents relevant to public health and/or PHHR
#
#
#
# ------------------------
# CLINICAL CHARACTERISTICS AND OUTCOMES OF RESPIRATORY SYNCYTIAL VIRUS INFECTION IN PREGNANT WOMEN
# ------------------------
# Provincial government and regional health authorities
#
#
#
# ------------------------
# ESTIMATING THE RISKS FROM COVID-19 INFECTION IN ADULT CHEMOTHERAPY PATIENTS
# ------------------------
#  Given that the politics of American anti-statism resist increasing federal administration of public health surveillance, alternative approaches for improving collection, analysis, and reporting also warrant consideration
#
#
#
# ------------------------
# PREGNANCY AND PERINATAL OUTCOMES OF WOMEN WITH SEVERE ACUTE RESPIRATORY SYNDROME
# ------------------------
# Most states can successfully conduct public health surveillance in compliance with IHR 2005
#
#
#
# ------------------------
# VIRAL CO-INFECTIONS IN PEDIATRIC PATIENTS HOSPITALIZED WITH LOWER TRACT ACUTE RESPIRATORY INFECTIONS
# ------------------------
#  Laws, regulations, and policy bases of health emergency management assessment should be strengthened, especially after the establishment of the National Emergency Management Department in April 2018
#
#
#
# ------------------------
# RESPIRATORY VIRUS INFECTION AMONG HOSPITALIZED ADULT PATIENTS WITH OR WITHOUT CLINICALLY APPARENT RESPIRATORY INFECTION: A PROSPECTIVE COHORT STUDY
# ------------------------
#  Data on such indicators are reported by health care providers and diagnostic laboratories, by legal mandate or voluntary agreement, and are collected by surveillance specialists in governmental health agencies
#
#
#
# ------------------------
# RAPID DIAGNOSIS OF RESPIRATORY VIRUS INFECTIONS PATIENTS WITH ACUTE RESPIRATORY DISEASE IN
# ------------------------
#  They report on a case study of public mental health policy implementation in England involving local implementation teams to deliver the policy
#
#
#
# ------------------------
# VIRAL CO-INFECTIONS IN PEDIATRIC PATIENTS HOSPITALIZED WITH LOWER TRACT ACUTE RESPIRATORY INFECTIONS
# ------------------------
#  Laws, regulations and policy bases for health emergency management assessment also need to attend to differences and linkages between national health emergencies and national emergency laws, regulations, and policies
#
#
#
# ------------------------
# RESPIRATORY VIRUS INFECTION AMONG HOSPITALIZED ADULT PATIENTS WITH OR WITHOUT CLINICALLY APPARENT RESPIRATORY INFECTION: A PROSPECTIVE COHORT STUDY
# ------------------------
#  In 2005, the WHO established international health regulations (IHR) for surveillance activities that offer the WHO's 193 member states a multilateral legal framework for surveillance, notification, and responses to disease outbreaks and other emergencies with potential international public health implications
#
#
#
# ------------------------
# ESTIMATING THE RISKS FROM COVID-19 INFECTION IN ADULT CHEMOTHERAPY PATIENTS
# ------------------------
#  Cyber intelligence and disease surveillance are both conducted by military and civilian agencies because malware and disease are both interpreted as threats to national security
#
#
#
# ------------------------
# RISK FACTORS FOR SEVERE BRONCHIOLITIS CAUSED BY RESPIRATORY VIRUS INFECTIONS AMONG MEXICAN CHILDREN IN AN EMERGENCY DEPARTMENT
# ------------------------
#  Primary documents included: guidance documents, statements of recommendations, interim or final government, advisory or scientific group reports and pandemic plans
#
#
#
# ------------------------
# ESTIMATING THE RISKS FROM COVID-19 INFECTION IN ADULT CHEMOTHERAPY PATIENTS
# ------------------------
#  31(p83) Proposals for the federal government to establish authoritative standards and agencies have gained little traction
#
#
#
# ------------------------
# ESTIMATING THE RISKS FROM COVID-19 INFECTION IN ADULT CHEMOTHERAPY PATIENTS
# ------------------------
#  The PHS appointed epidemiologists to serve in state health departments in 1914, but the federal government did not establish an agency dedicated to disease surveillance until 1946
#
#
#
# ------------------------
# STATINS MAY DECREASE THE FATALITY RATE OF MIDDLE EAST RESPIRATORY SYNDROME INFECTION
# ------------------------
#  A review of the pandemic plans of the Public Health Agency of Canada, provincial and territorial governments has identified needs in pediatric planning
#
#
#
# ------------------------
# RESPIRATORY DISEASE IN PREGNANCY
# ------------------------
#  The IHR cannot effectively govern global health security unless governments promptly report novel infections
#
#
#
# ------------------------
# RISK FACTORS FOR SEVERE BRONCHIOLITIS CAUSED BY RESPIRATORY VIRUS INFECTIONS AMONG MEXICAN CHILDREN IN AN EMERGENCY DEPARTMENT
# ------------------------
# This policy analysis used a multiple case study design to examine policies at the federal, provincial and local levels of public health in Canada
